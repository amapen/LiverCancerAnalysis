# %%
import math
import pickle
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import statsmodels.formula.api as smf

from scipy.special import ndtri
from decimal import Decimal, ROUND_HALF_UP
from sklearn.calibration import calibration_curve
from sklearn.model_selection import train_test_split

pd.set_option('display.max_columns', 200)

# %%
df = pd.read_csv('データ抽出.csv')
df
# Out:
#             ID          BD  肝癌症例   Age  Gender  初回治療  No_of_Admission  \
# 0     11359162  1925/07/02     1  74.0       1  PEIT              1.0
# 1     11359162  1925/07/02     1  74.0       1  PEIT              2.0
# 2     11359162  1925/07/02     1  76.0       1  PEIT              3.0
# 3     20146876  1948/07/02     1  65.0       1   無治療              1.0
# 4     13170941  1929/04/19     1  74.0       1   TAE              1.0
# ...        ...         ...   ...   ...     ...   ...              ...
# 6379  11338154  1925/02/13     1  83.0       1  PEIT              7.0
# 6380  11338154  1925/02/13     1  85.0       1  PEIT              8.0
# 6381  11338154  1925/02/13     1  86.0       1  PEIT              9.0
# 6382  11338154  1925/02/13     1  86.0       1  PEIT             10.0
# 6383  17453700  1948/01/29     1  71.0       1   OPE              1.0
#
#       naïveHCC       初回入院日         入院日  Last_Treatment basal_disease  \
# 0          1.0  2000/04/10  2000/04/10               0            LC
# 1          NaN  2000/04/10  2001/04/17             372            LC
# 2          NaN  2000/04/10  2001/08/21             126            LC
# 3          1.0  2014/05/08  2014/05/08               0            LC
# 4          1.0  2003/12/02  2003/12/02               0      nonBnonC
# ...        ...         ...         ...             ...           ...
# 6379       NaN         NaN  2008/06/02             139            CH
# 6380       NaN         NaN  2010/03/15             651            CH
# 6381       NaN         NaN  2011/02/21             343            CH
# 6382       NaN         NaN  2011/07/04             133            CH
# 6383       1.0  2019/07/18  2019/07/18               0            CH
#
#         etiology  etiology_C1B2BC3Alc4NBNC5  HCV  HBV  nonBnonC     HT    BW  \
# 0              C                        1.0  1.0  0.0       0.0    NaN   NaN
# 1              C                        1.0  1.0  NaN       NaN    NaN   NaN
# 2              C                        1.0  1.0  NaN       NaN    NaN   NaN
# 3              C                        1.0  1.0  0.0       0.0  1.644  50.4
# 4       nonBnonC                        5.0  0.0  0.0       1.0    NaN   NaN
# ...          ...                        ...  ...  ...       ...    ...   ...
# 6379           C                        1.0  1.0  NaN       NaN    NaN   NaN
# 6380           C                        1.0  1.0  NaN       NaN    NaN   NaN
# 6381           C                        1.0  1.0  NaN       NaN    NaN   NaN
# 6382           C                        1.0  1.0  NaN       NaN    NaN   NaN
# 6383  C(IFN SVR)                        1.0  1.0  0.0       0.0  1.620    77
#
#            BMI   PS    AST    ALT   Plt  T.Bil  Alb     PT PT.INR     AFP  \
# 0          NaN  NaN  200.0  294.0  10.0    0.9  4.0   98.3   1.01   129.8
# 1          NaN  NaN   59.0   53.0   7.8    0.8  4.3   87.0    NaN  2506.0
# 2          NaN  NaN   50.0   50.0   7.4    0.7  3.7  105.4   0.98  3408.4
# 3     18.64777  0.0  194.0  100.0  19.9    3.6  3.3   74.0   1.17  1020.0
# 4          NaN  NaN   44.0   16.0  16.5    0.5  3.7   99.6   1.01     3.6
# ...        ...  ...    ...    ...   ...    ...  ...    ...    ...     ...
# 6379       NaN  NaN   35.0   30.0  33.0    0.7  4.0   74.1    NaN     5.1
# 6380       NaN  NaN   22.0   13.0  20.0    0.4  3.6   84.6    NaN     2.8
# 6381       NaN  NaN   20.0   17.0  19.4    0.4  3.6   90.2   1.05     7.6
# 6382       NaN  NaN   29.0   23.0  19.4    0.5  4.0   95.9   1.03     2.5
# 6383  29.34004  0.0   40.0   52.0  15.8    1.0  4.5  108.0   0.96     3.5
#
#         L3     PIVKA      FIB4  ALBI_score ALBI_grade HCC_size  HCC_No HCC実数  \
# 0      NaN      18.0  8.631535   -2.616423          1      3.5     1.0     1
# 1      9.2       NaN  7.688670   -2.905183          1        4     NaN    多発
# 2     23.2      28.0  7.262178   -2.433458         2a        4     NaN    多発
# 3     70.9  211840.0  6.336683   -1.624063         2b      6.7     3.0     3
# 4      0.0      23.0  4.933333   -2.529902         2a       12     1.0     1
# ...    ...       ...       ...         ...        ...      ...     ...   ...
# 6379  22.8      70.0  1.607206   -2.688458          1        2     3.0     3
# 6380  18.2      13.0  2.593223   -2.508863         2a        1     1.0     1
# 6381  56.4      13.0  2.150316   -2.508863         2a      1.5     2.0     2
# 6382   0.0       9.0  2.680593   -2.784902          1        1     2.0     2
# 6383   0.5      46.0  2.492640   -3.011223          1        1     2.5     1
#
#       Vp_grade  Meta0or1    治療法解析用  Death1Alive0       入院日.1   最終観察日_退院日  \
# 0            0       0.0  Ablation             1  2000/04/17  2001/12/24
# 1            0       0.0       TAE             1  2001/04/19  2001/12/24
# 2            0       0.0  Ablation             1  2001/08/30  2001/12/24
# 3            2       0.0       無治療             1  2014/05/08  2014/07/12
# 4            3       0.0       TAE             1  2003/12/04  2004/09/15
# ...        ...       ...       ...           ...         ...         ...
# 6379         0       0.0  Ablation             1  2008/06/02  2011/11/21
# 6380         0       0.0       TAE             1  2010/03/15  2011/11/21
# 6381         0       0.0       TAE             1  2011/02/21  2011/11/21
# 6382         0       0.0       TAE             1  2011/07/04  2011/11/21
# 6383         0       0.0       OPE             0  2019/07/18  2020/04/03
#
#      OS_day     OS_Month       死亡年月日   死因        GNRI  GNRI栄養リスク1良4最悪  男性標準体重  \
# 0       616  20.53333333  2001/12/24  肝癌死         NaN             NaN     NaN
# 1       249          8.3         NaN  NaN         NaN             NaN     NaN
# 2       116  3.866666667         NaN  NaN         NaN             NaN     NaN
# 3        65  2.166666667         NaN  肝不全   83.704105             3.0    60.8
# 4       286  9.533333333  2004/09/15  肝癌死         NaN             NaN     NaN
# ...     ...          ...         ...  ...         ...             ...     ...
# 6379   1267  42.23333333         NaN  NaN         NaN             NaN     NaN
# 6380    616  20.53333333         NaN  NaN         NaN             NaN     NaN
# 6381    273          9.1         NaN  NaN         NaN             NaN     NaN
# 6382    140  4.666666667         NaN  NaN         NaN             NaN     NaN
# 6383    260  8.666666667         NaN  NaN  121.427034             1.0    59.0
#
#       女性標準体重
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 6379     NaN
# 6380     NaN
# 6381     NaN
# 6382     NaN
# 6383     NaN
#
# [6384 rows x 51 columns]

# %% [markdown]
# # データの読み込み

# %%
df = pd.read_csv('データ抽出.csv')
df
# Out:
#             ID          BD  肝癌症例   Age  Gender  初回治療  No_of_Admission  \
# 0     11359162  1925/07/02     1  74.0       1  PEIT              1.0
# 1     11359162  1925/07/02     1  74.0       1  PEIT              2.0
# 2     11359162  1925/07/02     1  76.0       1  PEIT              3.0
# 3     20146876  1948/07/02     1  65.0       1   無治療              1.0
# 4     13170941  1929/04/19     1  74.0       1   TAE              1.0
# ...        ...         ...   ...   ...     ...   ...              ...
# 6379  11338154  1925/02/13     1  83.0       1  PEIT              7.0
# 6380  11338154  1925/02/13     1  85.0       1  PEIT              8.0
# 6381  11338154  1925/02/13     1  86.0       1  PEIT              9.0
# 6382  11338154  1925/02/13     1  86.0       1  PEIT             10.0
# 6383  17453700  1948/01/29     1  71.0       1   OPE              1.0
#
#       naïveHCC       初回入院日         入院日  Last_Treatment basal_disease  \
# 0          1.0  2000/04/10  2000/04/10               0            LC
# 1          NaN  2000/04/10  2001/04/17             372            LC
# 2          NaN  2000/04/10  2001/08/21             126            LC
# 3          1.0  2014/05/08  2014/05/08               0            LC
# 4          1.0  2003/12/02  2003/12/02               0      nonBnonC
# ...        ...         ...         ...             ...           ...
# 6379       NaN         NaN  2008/06/02             139            CH
# 6380       NaN         NaN  2010/03/15             651            CH
# 6381       NaN         NaN  2011/02/21             343            CH
# 6382       NaN         NaN  2011/07/04             133            CH
# 6383       1.0  2019/07/18  2019/07/18               0            CH
#
#         etiology  etiology_C1B2BC3Alc4NBNC5  HCV  HBV  nonBnonC     HT    BW  \
# 0              C                        1.0  1.0  0.0       0.0    NaN   NaN
# 1              C                        1.0  1.0  NaN       NaN    NaN   NaN
# 2              C                        1.0  1.0  NaN       NaN    NaN   NaN
# 3              C                        1.0  1.0  0.0       0.0  1.644  50.4
# 4       nonBnonC                        5.0  0.0  0.0       1.0    NaN   NaN
# ...          ...                        ...  ...  ...       ...    ...   ...
# 6379           C                        1.0  1.0  NaN       NaN    NaN   NaN
# 6380           C                        1.0  1.0  NaN       NaN    NaN   NaN
# 6381           C                        1.0  1.0  NaN       NaN    NaN   NaN
# 6382           C                        1.0  1.0  NaN       NaN    NaN   NaN
# 6383  C(IFN SVR)                        1.0  1.0  0.0       0.0  1.620    77
#
#            BMI   PS    AST    ALT   Plt  T.Bil  Alb     PT PT.INR     AFP  \
# 0          NaN  NaN  200.0  294.0  10.0    0.9  4.0   98.3   1.01   129.8
# 1          NaN  NaN   59.0   53.0   7.8    0.8  4.3   87.0    NaN  2506.0
# 2          NaN  NaN   50.0   50.0   7.4    0.7  3.7  105.4   0.98  3408.4
# 3     18.64777  0.0  194.0  100.0  19.9    3.6  3.3   74.0   1.17  1020.0
# 4          NaN  NaN   44.0   16.0  16.5    0.5  3.7   99.6   1.01     3.6
# ...        ...  ...    ...    ...   ...    ...  ...    ...    ...     ...
# 6379       NaN  NaN   35.0   30.0  33.0    0.7  4.0   74.1    NaN     5.1
# 6380       NaN  NaN   22.0   13.0  20.0    0.4  3.6   84.6    NaN     2.8
# 6381       NaN  NaN   20.0   17.0  19.4    0.4  3.6   90.2   1.05     7.6
# 6382       NaN  NaN   29.0   23.0  19.4    0.5  4.0   95.9   1.03     2.5
# 6383  29.34004  0.0   40.0   52.0  15.8    1.0  4.5  108.0   0.96     3.5
#
#         L3     PIVKA      FIB4  ALBI_score ALBI_grade HCC_size  HCC_No HCC実数  \
# 0      NaN      18.0  8.631535   -2.616423          1      3.5     1.0     1
# 1      9.2       NaN  7.688670   -2.905183          1        4     NaN    多発
# 2     23.2      28.0  7.262178   -2.433458         2a        4     NaN    多発
# 3     70.9  211840.0  6.336683   -1.624063         2b      6.7     3.0     3
# 4      0.0      23.0  4.933333   -2.529902         2a       12     1.0     1
# ...    ...       ...       ...         ...        ...      ...     ...   ...
# 6379  22.8      70.0  1.607206   -2.688458          1        2     3.0     3
# 6380  18.2      13.0  2.593223   -2.508863         2a        1     1.0     1
# 6381  56.4      13.0  2.150316   -2.508863         2a      1.5     2.0     2
# 6382   0.0       9.0  2.680593   -2.784902          1        1     2.0     2
# 6383   0.5      46.0  2.492640   -3.011223          1        1     2.5     1
#
#       Vp_grade  Meta0or1    治療法解析用  Death1Alive0       入院日.1   最終観察日_退院日  \
# 0            0       0.0  Ablation             1  2000/04/17  2001/12/24
# 1            0       0.0       TAE             1  2001/04/19  2001/12/24
# 2            0       0.0  Ablation             1  2001/08/30  2001/12/24
# 3            2       0.0       無治療             1  2014/05/08  2014/07/12
# 4            3       0.0       TAE             1  2003/12/04  2004/09/15
# ...        ...       ...       ...           ...         ...         ...
# 6379         0       0.0  Ablation             1  2008/06/02  2011/11/21
# 6380         0       0.0       TAE             1  2010/03/15  2011/11/21
# 6381         0       0.0       TAE             1  2011/02/21  2011/11/21
# 6382         0       0.0       TAE             1  2011/07/04  2011/11/21
# 6383         0       0.0       OPE             0  2019/07/18  2020/04/03
#
#      OS_day     OS_Month       死亡年月日   死因        GNRI  GNRI栄養リスク1良4最悪  男性標準体重  \
# 0       616  20.53333333  2001/12/24  肝癌死         NaN             NaN     NaN
# 1       249          8.3         NaN  NaN         NaN             NaN     NaN
# 2       116  3.866666667         NaN  NaN         NaN             NaN     NaN
# 3        65  2.166666667         NaN  肝不全   83.704105             3.0    60.8
# 4       286  9.533333333  2004/09/15  肝癌死         NaN             NaN     NaN
# ...     ...          ...         ...  ...         ...             ...     ...
# 6379   1267  42.23333333         NaN  NaN         NaN             NaN     NaN
# 6380    616  20.53333333         NaN  NaN         NaN             NaN     NaN
# 6381    273          9.1         NaN  NaN         NaN             NaN     NaN
# 6382    140  4.666666667         NaN  NaN         NaN             NaN     NaN
# 6383    260  8.666666667         NaN  NaN  121.427034             1.0    59.0
#
#       女性標準体重
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 6379     NaN
# 6380     NaN
# 6381     NaN
# 6382     NaN
# 6383     NaN
#
# [6384 rows x 51 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6384 entries, 0 to 6383
# Data columns (total 51 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ID                         6384 non-null   int64
#  1   BD                         6372 non-null   object
#  2   肝癌症例                       6384 non-null   int64
#  3   Age                        6383 non-null   float64
#  4   Gender                     6384 non-null   int64
#  5   初回治療                       6381 non-null   object
#  6   No_of_Admission            6364 non-null   float64
#  7   naïveHCC                   2008 non-null   float64
#  8   初回入院日                      5538 non-null   object
#  9   入院日                        6384 non-null   object
#  10  Last_Treatment             6384 non-null   int64
#  11  basal_disease              6234 non-null   object
#  12  etiology                   6301 non-null   object
#  13  etiology_C1B2BC3Alc4NBNC5  6307 non-null   float64
#  14  HCV                        6280 non-null   float64
#  15  HBV                        3667 non-null   float64
#  16  nonBnonC                   3732 non-null   float64
#  17  HT                         2392 non-null   float64
#  18  BW                         2396 non-null   object
#  19  BMI                        2387 non-null   float64
#  20  PS                         2622 non-null   float64
#  21  AST                        6255 non-null   float64
#  22  ALT                        6256 non-null   float64
#  23  Plt                        6253 non-null   float64
#  24  T.Bil                      6258 non-null   float64
#  25  Alb                        6235 non-null   float64
#  26  PT                         6143 non-null   float64
#  27  PT.INR                     3495 non-null   object
#  28  AFP                        6195 non-null   float64
#  29  L3                         5673 non-null   float64
#  30  PIVKA                      6122 non-null   float64
#  31  FIB4                       6245 non-null   float64
#  32  ALBI_score                 6250 non-null   float64
#  33  ALBI_grade                 6250 non-null   object
#  34  HCC_size                   6143 non-null   object
#  35  HCC_No                     5945 non-null   float64
#  36  HCC実数                      6161 non-null   object
#  37  Vp_grade                   6384 non-null   int64
#  38  Meta0or1                   6240 non-null   float64
#  39  治療法解析用                     6368 non-null   object
#  40  Death1Alive0               6384 non-null   int64
#  41  入院日.1                      6383 non-null   object
#  42  最終観察日_退院日                  6379 non-null   object
#  43  OS_day                     6379 non-null   object
#  44  OS_Month                   6374 non-null   object
#  45  死亡年月日                      118 non-null    object
#  46  死因                         1473 non-null   object
#  47  GNRI                       2387 non-null   float64
#  48  GNRI栄養リスク1良4最悪             2387 non-null   float64
#  49  男性標準体重                     1758 non-null   float64
#  50  女性標準体重                     629 non-null    float64
# dtypes: float64(27), int64(6), object(18)
# memory usage: 2.5+ MB

# %% [markdown]
# # 前処理

# %%
cut = 0

# %% [markdown]
# ## 治療法

# %%
df['治療法解析用'].value_counts()
# Out:
# TAE         2764
# Ablation    1685
# OPE          806
# 化学療法         666
# 無治療          399
# 放射線治療         48
# Name: 治療法解析用, dtype: int64

# %%
cut += df['治療法解析用'].isnull().sum()
df['治療法解析用'].isnull().sum()
# Out:
# 16

# %%
df = df.dropna(subset=['治療法解析用'])

# %%
df = pd.get_dummies(df, columns=['治療法解析用'], prefix='', prefix_sep='')
df = df.drop(columns='無治療')
df.rename(columns={'化学療法': 'MTA', '放射線治療': 'Radiation'}, inplace=True)
df
# Out:
#             ID          BD  肝癌症例   Age  Gender  初回治療  No_of_Admission  \
# 0     11359162  1925/07/02     1  74.0       1  PEIT              1.0
# 1     11359162  1925/07/02     1  74.0       1  PEIT              2.0
# 2     11359162  1925/07/02     1  76.0       1  PEIT              3.0
# 3     20146876  1948/07/02     1  65.0       1   無治療              1.0
# 4     13170941  1929/04/19     1  74.0       1   TAE              1.0
# ...        ...         ...   ...   ...     ...   ...              ...
# 6379  11338154  1925/02/13     1  83.0       1  PEIT              7.0
# 6380  11338154  1925/02/13     1  85.0       1  PEIT              8.0
# 6381  11338154  1925/02/13     1  86.0       1  PEIT              9.0
# 6382  11338154  1925/02/13     1  86.0       1  PEIT             10.0
# 6383  17453700  1948/01/29     1  71.0       1   OPE              1.0
#
#       naïveHCC       初回入院日         入院日  Last_Treatment basal_disease  \
# 0          1.0  2000/04/10  2000/04/10               0            LC
# 1          NaN  2000/04/10  2001/04/17             372            LC
# 2          NaN  2000/04/10  2001/08/21             126            LC
# 3          1.0  2014/05/08  2014/05/08               0            LC
# 4          1.0  2003/12/02  2003/12/02               0      nonBnonC
# ...        ...         ...         ...             ...           ...
# 6379       NaN         NaN  2008/06/02             139            CH
# 6380       NaN         NaN  2010/03/15             651            CH
# 6381       NaN         NaN  2011/02/21             343            CH
# 6382       NaN         NaN  2011/07/04             133            CH
# 6383       1.0  2019/07/18  2019/07/18               0            CH
#
#         etiology  etiology_C1B2BC3Alc4NBNC5  HCV  HBV  nonBnonC     HT    BW  \
# 0              C                        1.0  1.0  0.0       0.0    NaN   NaN
# 1              C                        1.0  1.0  NaN       NaN    NaN   NaN
# 2              C                        1.0  1.0  NaN       NaN    NaN   NaN
# 3              C                        1.0  1.0  0.0       0.0  1.644  50.4
# 4       nonBnonC                        5.0  0.0  0.0       1.0    NaN   NaN
# ...          ...                        ...  ...  ...       ...    ...   ...
# 6379           C                        1.0  1.0  NaN       NaN    NaN   NaN
# 6380           C                        1.0  1.0  NaN       NaN    NaN   NaN
# 6381           C                        1.0  1.0  NaN       NaN    NaN   NaN
# 6382           C                        1.0  1.0  NaN       NaN    NaN   NaN
# 6383  C(IFN SVR)                        1.0  1.0  0.0       0.0  1.620    77
#
#            BMI   PS    AST    ALT   Plt  T.Bil  Alb     PT PT.INR     AFP  \
# 0          NaN  NaN  200.0  294.0  10.0    0.9  4.0   98.3   1.01   129.8
# 1          NaN  NaN   59.0   53.0   7.8    0.8  4.3   87.0    NaN  2506.0
# 2          NaN  NaN   50.0   50.0   7.4    0.7  3.7  105.4   0.98  3408.4
# 3     18.64777  0.0  194.0  100.0  19.9    3.6  3.3   74.0   1.17  1020.0
# 4          NaN  NaN   44.0   16.0  16.5    0.5  3.7   99.6   1.01     3.6
# ...        ...  ...    ...    ...   ...    ...  ...    ...    ...     ...
# 6379       NaN  NaN   35.0   30.0  33.0    0.7  4.0   74.1    NaN     5.1
# 6380       NaN  NaN   22.0   13.0  20.0    0.4  3.6   84.6    NaN     2.8
# 6381       NaN  NaN   20.0   17.0  19.4    0.4  3.6   90.2   1.05     7.6
# 6382       NaN  NaN   29.0   23.0  19.4    0.5  4.0   95.9   1.03     2.5
# 6383  29.34004  0.0   40.0   52.0  15.8    1.0  4.5  108.0   0.96     3.5
#
#         L3     PIVKA      FIB4  ALBI_score ALBI_grade HCC_size  HCC_No HCC実数  \
# 0      NaN      18.0  8.631535   -2.616423          1      3.5     1.0     1
# 1      9.2       NaN  7.688670   -2.905183          1        4     NaN    多発
# 2     23.2      28.0  7.262178   -2.433458         2a        4     NaN    多発
# 3     70.9  211840.0  6.336683   -1.624063         2b      6.7     3.0     3
# 4      0.0      23.0  4.933333   -2.529902         2a       12     1.0     1
# ...    ...       ...       ...         ...        ...      ...     ...   ...
# 6379  22.8      70.0  1.607206   -2.688458          1        2     3.0     3
# 6380  18.2      13.0  2.593223   -2.508863         2a        1     1.0     1
# 6381  56.4      13.0  2.150316   -2.508863         2a      1.5     2.0     2
# 6382   0.0       9.0  2.680593   -2.784902          1        1     2.0     2
# 6383   0.5      46.0  2.492640   -3.011223          1        1     2.5     1
#
#       Vp_grade  Meta0or1  Death1Alive0       入院日.1   最終観察日_退院日 OS_day  \
# 0            0       0.0             1  2000/04/17  2001/12/24    616
# 1            0       0.0             1  2001/04/19  2001/12/24    249
# 2            0       0.0             1  2001/08/30  2001/12/24    116
# 3            2       0.0             1  2014/05/08  2014/07/12     65
# 4            3       0.0             1  2003/12/04  2004/09/15    286
# ...        ...       ...           ...         ...         ...    ...
# 6379         0       0.0             1  2008/06/02  2011/11/21   1267
# 6380         0       0.0             1  2010/03/15  2011/11/21    616
# 6381         0       0.0             1  2011/02/21  2011/11/21    273
# 6382         0       0.0             1  2011/07/04  2011/11/21    140
# 6383         0       0.0             0  2019/07/18  2020/04/03    260
#
#          OS_Month       死亡年月日   死因        GNRI  GNRI栄養リスク1良4最悪  男性標準体重  \
# 0     20.53333333  2001/12/24  肝癌死         NaN             NaN     NaN
# 1             8.3         NaN  NaN         NaN             NaN     NaN
# 2     3.866666667         NaN  NaN         NaN             NaN     NaN
# 3     2.166666667         NaN  肝不全   83.704105             3.0    60.8
# 4     9.533333333  2004/09/15  肝癌死         NaN             NaN     NaN
# ...           ...         ...  ...         ...             ...     ...
# 6379  42.23333333         NaN  NaN         NaN             NaN     NaN
# 6380  20.53333333         NaN  NaN         NaN             NaN     NaN
# 6381          9.1         NaN  NaN         NaN             NaN     NaN
# 6382  4.666666667         NaN  NaN         NaN             NaN     NaN
# 6383  8.666666667         NaN  NaN  121.427034             1.0    59.0
#
#       女性標準体重  Ablation  OPE  TAE  MTA  Radiation
# 0        NaN         1    0    0    0          0
# 1        NaN         0    0    1    0          0
# 2        NaN         1    0    0    0          0
# 3        NaN         0    0    0    0          0
# 4        NaN         0    0    1    0          0
# ...      ...       ...  ...  ...  ...        ...
# 6379     NaN         1    0    0    0          0
# 6380     NaN         0    0    1    0          0
# 6381     NaN         0    0    1    0          0
# 6382     NaN         0    0    1    0          0
# 6383     NaN         0    1    0    0          0
#
# [6368 rows x 55 columns]

# %% [markdown]
# ## 前回治療からの期間

# %%
cut += df['Last_Treatment'].isnull().sum()
df['Last_Treatment'].isnull().sum()
# Out:
# 0

# %%
df['Last_Treatment'] = df['Last_Treatment'].replace('#NUM!', 0).replace(0, 10000).astype(int)
df['Last_Treatment'].value_counts()
# Out:
# 10000    2324
# 119       178
# 126       144
# 112       138
# 133       127
#          ...
# 1385        1
# 3436        1
# 1389        1
# 1393        1
# 2035        1
# Name: Last_Treatment, Length: 942, dtype: int64

# %%
df['Last_Treatment'] = np.log10(df['Last_Treatment'] + 1)
df['Last_Treatment'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 年齢

# %%
cut += df['Age'].isnull().sum()
df['Age'].isnull().sum()
# Out:
# 1

# %%
df = df.dropna(subset=['Age'])

# %% [markdown]
# ## 性別

# %%
cut += df['Gender'].isnull().sum()
df['Gender'].isnull().sum()
# Out:
# 0

# %%
df['Gender'] = df['Gender'].replace(1,  0).replace(2, 1)
df['Gender'].value_counts()
# Out:
# <ipython-input-16-61c53c01eb90>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender'] = df['Gender'].replace(1,  0).replace(2, 1)
# 0    4772
# 1    1595
# Name: Gender, dtype: int64

# %% [markdown]
# ## BMI

# %%
df['BMI'].isnull().sum()
# Out:
# 3987

# %%
df['BMI'].mean()
# Out:
# 23.55354519539412

# %%
df['BMI'] = df['BMI'].fillna(df['BMI'].mean())
df['BMI'].value_counts()
# Out:
# <ipython-input-19-31946bc79507>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['BMI'] = df['BMI'].fillna(df['BMI'].mean())
# 23.553545    3987
# 17.985908       6
# 19.818927       6
# 21.504470       5
# 22.038567       5
#              ...
# 24.606949       1
# 21.785199       1
# 25.834476       1
# 23.643932       1
# 19.927729       1
# Name: BMI, Length: 2011, dtype: int64

# %% [markdown]
# ## 手術回数

# %%
cut += df['No_of_Admission'].isnull().sum()
df['No_of_Admission'].isnull().sum()
# Out:
# 20

# %%
df = df.dropna(subset=['No_of_Admission'])
df['No_of_Admission'] = df['No_of_Admission'].astype(int)
df['No_of_Admission'].value_counts()
# Out:
# 1     2090
# 2     1107
# 3      788
# 4      585
# 5      443
# 6      338
# 7      254
# 8      192
# 9      145
# 10     116
# 11      90
# 12      65
# 13      41
# 14      28
# 15      22
# 16      15
# 17      10
# 18       8
# 19       4
# 20       3
# 21       2
# 22       1
# Name: No_of_Admission, dtype: int64

# %% [markdown]
# ## 個数

# %%
df['HCC_No'].value_counts()
# Out:
# 1.0    2376
# 6.0    1622
# 2.0     863
# 3.0     439
# 4.0     301
# 5.0     272
# 0.0      44
# 2.5       1
# Name: HCC_No, dtype: int64

# %%
cut += df['HCC_No'].isnull().sum()
df['HCC_No'].isnull().sum()
# Out:
# 429

# %%
#df['HCC_No'] = df['HCC_No'].fillna(5).astype(int)
df = df.dropna(subset=['HCC_No'])
df['HCC_No'] = df['HCC_No'].astype(int)
df['HCC_No'].value_counts()
# Out:
# 1    2376
# 6    1622
# 2     864
# 3     439
# 4     301
# 5     272
# 0      44
# Name: HCC_No, dtype: int64

# %%
before = 0
l = []
for i, n in zip(df['ID'], df['HCC_No']):
    if i == before:
        l.append(l[-1] + n)
    else:
        l.append(n)
        before = i

df['No_Cumsum'] = l
df['No_Cumsum'].value_counts()
# Out:
# 1     1383
# 2      730
# 3      441
# 6      418
# 4      312
#       ...
# 70       2
# 76       1
# 86       1
# 82       1
# 95       1
# Name: No_Cumsum, Length: 91, dtype: int64

# %% [markdown]
# ## サイズ

# %%
df['HCC_size'].value_counts()
# Out:
# 1.5     727
# 1       696
# 2       430
# 3       301
# 2.5     278
#        ...
# 18.6      1
# 15.8      1
# 16.4      1
# 12.6      1
# 12.3      1
# Name: HCC_size, Length: 145, dtype: int64

# %%
cut += df['HCC_size'].isnull().sum()
df['HCC_size'].isnull().sum()
# Out:
# 41

# %%
df = df.replace('diffuse', '1')
df = df.dropna(subset=['HCC_size'])
df['HCC_size'] = df['HCC_size'].map(lambda x: int(Decimal(str(x)).quantize(Decimal('0'), rounding=ROUND_HALF_UP)))
df['HCC_size'].value_counts()
# Out:
# 2     2107
# 1     1291
# 3     1013
# 4      513
# 5      311
# 6      162
# 7      108
# 8       77
# 9       61
# 10      54
# 0       40
# 12      33
# 11      28
# 13      24
# 15      22
# 14      19
# 16       7
# 17       3
# 19       2
# 18       1
# 23       1
# Name: HCC_size, dtype: int64

# %% [markdown]
# ## サイズ*個数

# %%
df['NoSize'] = df['HCC_No'] * df['HCC_size']
df['NoSize'].value_counts()
# Out:
# 2     1058
# 4      648
# 6      623
# 12     609
# 1      562
# 3      492
# 18     352
# 8      211
# 24     189
# 5      174
# 10     162
# 30     149
# 9       97
# 15      85
# 36      58
# 7       48
# 0       40
# 16      39
# 42      35
# 20      35
# 48      32
# 60      23
# 14      20
# 13      15
# 54      14
# 21      10
# 11      10
# 72      10
# 25       8
# 66       8
# 27       7
# 45       6
# 78       6
# 28       6
# 84       4
# 22       4
# 44       4
# 35       3
# 32       3
# 39       2
# 51       2
# 33       2
# 96       2
# 40       2
# 70       1
# 90       1
# 50       1
# 26       1
# 69       1
# 19       1
# 17       1
# 57       1
# Name: NoSize, dtype: int64

# %%
cut += df['NoSize'].isnull().sum()
df['NoSize'].isnull().sum()
# Out:
# 0

# %%
before = 0
l = []
for i, n in zip(df['ID'], df['NoSize']):
    if i == before:
        l.append(l[-1] + n)
    else:
        l.append(n)
        before = i

l_10 = [i//10 for i in l]
df['NoSize_Cumsum'] = l_10
df['NoSize_Cumsum'].value_counts()
# Out:
# 0     2562
# 1     1055
# 2      536
# 3      414
# 4      303
# 5      192
# 6      182
# 7      147
# 8       99
# 9       77
# 10      60
# 11      45
# 12      39
# 13      34
# 15      24
# 14      24
# 16      16
# 17      13
# 19      13
# 18       9
# 21       6
# 20       5
# 22       5
# 23       5
# 26       3
# 24       2
# 27       1
# 29       1
# 30       1
# 25       1
# 32       1
# 28       1
# 31       1
# Name: NoSize_Cumsum, dtype: int64

# %% [markdown]
# ## PS

# %%
df['PS'].value_counts()
# Out:
# 0.0    1967
# 1.0     311
# 2.0     141
# 3.0     102
# 4.0      48
# Name: PS, dtype: int64

# %%
#PSは0埋め
df['PS_Raw'] = df['PS'].fillna(0).astype(int)
df['PS_Raw'].value_counts()
# Out:
# 0    5275
# 1     311
# 2     141
# 3     102
# 4      48
# Name: PS_Raw, dtype: int64

# %% [markdown]
# ## ALBI

# %%
df['ALBI_score'].value_counts()
# Out:
# -2.784902    60
# -2.647643    55
# -2.869902    54
# -2.562643    53
# -2.348458    51
#              ..
# -0.571323     1
# -1.570283     1
# -1.378665     1
# -2.927743     1
# -1.303582     1
# Name: ALBI_score, Length: 801, dtype: int64

# %%
cut += df['ALBI_score'].isnull().sum()
df['ALBI_score'].isnull().sum()
# Out:
# 78

# %%
df = df.dropna(subset=['ALBI_score'])
df['ALBI_score'] = df['ALBI_score'].map(lambda x: int(Decimal(str(x*(-100))).quantize(Decimal('0'), rounding=ROUND_HALF_UP)))
df['ALBI_score'].value_counts()
# Out:
# 265    96
# 236    96
# 282    85
# 287    84
# 259    77
#        ..
# 58      1
# 46      1
# 38      1
# 26      1
# 367     1
# Name: ALBI_score, Length: 308, dtype: int64

# %% [markdown]
# ## ALBI_grade

# %%
df['ALBI_grade'].value_counts()
# Out:
# 1     2143
# 2b    2024
# 2a    1188
# 3      444
# Name: ALBI_grade, dtype: int64

# %%
cut += df['ALBI_grade'].isnull().sum()
df['ALBI_grade'].isnull().sum()
# Out:
# 0

# %%
df['ALBI_grade'] = df['ALBI_grade'].replace('3', '4').replace('2b', '3').replace('2a', '2').astype(int)
df = pd.get_dummies(df, columns=['ALBI_grade'])
df = df.drop(columns='ALBI_grade_1')
df
# Out:
#             ID          BD  肝癌症例   Age  Gender  初回治療  No_of_Admission  \
# 0     11359162  1925/07/02     1  74.0       0  PEIT                1
# 3     20146876  1948/07/02     1  65.0       0   無治療                1
# 4     13170941  1929/04/19     1  74.0       0   TAE                1
# 7     20197511  1936/11/20     1  81.0       0   OPE                1
# 8     15371855  1934/02/02     1  69.0       0   RFA                1
# ...        ...         ...   ...   ...     ...   ...              ...
# 6379  11338154  1925/02/13     1  83.0       0  PEIT                7
# 6380  11338154  1925/02/13     1  85.0       0  PEIT                8
# 6381  11338154  1925/02/13     1  86.0       0  PEIT                9
# 6382  11338154  1925/02/13     1  86.0       0  PEIT               10
# 6383  17453700  1948/01/29     1  71.0       0   OPE                1
#
#       naïveHCC       初回入院日         入院日  Last_Treatment basal_disease  \
# 0          1.0  2000/04/10  2000/04/10        4.000043            LC
# 3          1.0  2014/05/08  2014/05/08        4.000043            LC
# 4          1.0  2003/12/02  2003/12/02        4.000043      nonBnonC
# 7          1.0  2018/02/07  2018/02/07        4.000043            CH
# 8          1.0  2003/08/04  2003/08/04        4.000043            LC
# ...        ...         ...         ...             ...           ...
# 6379       NaN         NaN  2008/06/02        2.146128            CH
# 6380       NaN         NaN  2010/03/15        2.814248            CH
# 6381       NaN         NaN  2011/02/21        2.536558            CH
# 6382       NaN         NaN  2011/07/04        2.127105            CH
# 6383       1.0  2019/07/18  2019/07/18        4.000043            CH
#
#         etiology  etiology_C1B2BC3Alc4NBNC5  HCV  HBV  nonBnonC     HT    BW  \
# 0              C                        1.0  1.0  0.0       0.0    NaN   NaN
# 3              C                        1.0  1.0  0.0       0.0  1.644  50.4
# 4       nonBnonC                        5.0  0.0  0.0       1.0    NaN   NaN
# 7     C(DAA SVR)                        1.0  1.0  0.0       0.0  1.510  51.5
# 8              C                        1.0  1.0  0.0       0.0  1.600    55
# ...          ...                        ...  ...  ...       ...    ...   ...
# 6379           C                        1.0  1.0  NaN       NaN    NaN   NaN
# 6380           C                        1.0  1.0  NaN       NaN    NaN   NaN
# 6381           C                        1.0  1.0  NaN       NaN    NaN   NaN
# 6382           C                        1.0  1.0  NaN       NaN    NaN   NaN
# 6383  C(IFN SVR)                        1.0  1.0  0.0       0.0  1.620    77
#
#             BMI   PS    AST    ALT   Plt  T.Bil  Alb     PT PT.INR     AFP  \
# 0     23.553545  NaN  200.0  294.0  10.0    0.9  4.0   98.3   1.01   129.8
# 3     18.647770  0.0  194.0  100.0  19.9    3.6  3.3   74.0   1.17  1020.0
# 4     23.553545  NaN   44.0   16.0  16.5    0.5  3.7   99.6   1.01     3.6
# 7     22.586729  0.0   27.0   33.0  19.3    0.5  4.3   84.0    1.1   134.3
# 8     21.484375  0.0   59.0   44.0  22.4    0.9  3.5   87.5    NaN   152.7
# ...         ...  ...    ...    ...   ...    ...  ...    ...    ...     ...
# 6379  23.553545  NaN   35.0   30.0  33.0    0.7  4.0   74.1    NaN     5.1
# 6380  23.553545  NaN   22.0   13.0  20.0    0.4  3.6   84.6    NaN     2.8
# 6381  23.553545  NaN   20.0   17.0  19.4    0.4  3.6   90.2   1.05     7.6
# 6382  23.553545  NaN   29.0   23.0  19.4    0.5  4.0   95.9   1.03     2.5
# 6383  29.340040  0.0   40.0   52.0  15.8    1.0  4.5  108.0   0.96     3.5
#
#         L3     PIVKA      FIB4  ALBI_score  HCC_size  HCC_No HCC実数  Vp_grade  \
# 0      NaN      18.0  8.631535         262         4       1     1         0
# 3     70.9  211840.0  6.336683         162         7       3     3         2
# 4      0.0      23.0  4.933333         253        12       1     1         3
# 7      NaN      62.0  1.972579         304         2       1     1         0
# 8     35.9     720.0  2.739850         219         3       1     1         0
# ...    ...       ...       ...         ...       ...     ...   ...       ...
# 6379  22.8      70.0  1.607206         269         2       3     3         0
# 6380  18.2      13.0  2.593223         251         1       1     1         0
# 6381  56.4      13.0  2.150316         251         2       2     2         0
# 6382   0.0       9.0  2.680593         278         1       2     2         0
# 6383   0.5      46.0  2.492640         301         1       2     1         0
#
#       Meta0or1  Death1Alive0       入院日.1   最終観察日_退院日 OS_day     OS_Month  \
# 0          0.0             1  2000/04/17  2001/12/24    616  20.53333333
# 3          0.0             1  2014/05/08  2014/07/12     65  2.166666667
# 4          0.0             1  2003/12/04  2004/09/15    286  9.533333333
# 7          0.0             0  2018/02/07  2022/03/08   1490  49.66666667
# 8          0.0             1  2003/08/06  2006/04/25    993         33.1
# ...        ...           ...         ...         ...    ...          ...
# 6379       0.0             1  2008/06/02  2011/11/21   1267  42.23333333
# 6380       0.0             1  2010/03/15  2011/11/21    616  20.53333333
# 6381       0.0             1  2011/02/21  2011/11/21    273          9.1
# 6382       0.0             1  2011/07/04  2011/11/21    140  4.666666667
# 6383       0.0             0  2019/07/18  2020/04/03    260  8.666666667
#
#            死亡年月日   死因        GNRI  GNRI栄養リスク1良4最悪  男性標準体重  女性標準体重  Ablation  \
# 0     2001/12/24  肝癌死         NaN             NaN     NaN     NaN         1
# 3            NaN  肝不全   83.704105             3.0   60.80     NaN         0
# 4     2004/09/15  肝癌死         NaN             NaN     NaN     NaN         0
# 7            NaN  NaN  106.343256             1.0   50.75     NaN         0
# 8            NaN  肝癌死   92.001957             2.0   57.50     NaN         1
# ...          ...  ...         ...             ...     ...     ...       ...
# 6379         NaN  NaN         NaN             NaN     NaN     NaN         1
# 6380         NaN  NaN         NaN             NaN     NaN     NaN         0
# 6381         NaN  NaN         NaN             NaN     NaN     NaN         0
# 6382         NaN  NaN         NaN             NaN     NaN     NaN         0
# 6383         NaN  NaN  121.427034             1.0   59.00     NaN         0
#
#       OPE  TAE  MTA  Radiation  No_Cumsum  NoSize  NoSize_Cumsum  PS_Raw  \
# 0       0    0    0          0          1       4              0       0
# 3       0    0    0          0          3      21              2       0
# 4       0    1    0          0          1      12              1       0
# 7       1    0    0          0          1       2              0       0
# 8       0    0    0          0          1       3              0       0
# ...   ...  ...  ...        ...        ...     ...            ...     ...
# 6379    0    0    0          0         11       6              2       0
# 6380    0    1    0          0         12       1              2       0
# 6381    0    1    0          0         14       4              2       0
# 6382    0    1    0          0         16       2              3       0
# 6383    1    0    0          0          2       2              0       0
#
#       ALBI_grade_2  ALBI_grade_3  ALBI_grade_4
# 0                0             0             0
# 3                0             1             0
# 4                1             0             0
# 7                0             0             0
# 8                0             1             0
# ...            ...           ...           ...
# 6379             0             0             0
# 6380             1             0             0
# 6381             1             0             0
# 6382             0             0             0
# 6383             0             0             0
#
# [5799 rows x 61 columns]

# %% [markdown]
# ## AFP

# %%
#cut += df['AFP'].isnull().sum()
df['AFP'].isnull().sum()
# Out:
# 50

# %%
#AFPは0埋め
df['AFP'] = df['AFP'].fillna(0).astype(float)
df.insert(loc=0, column='AFP_100', value= -1)
df.loc[df['AFP'] < 100, 'AFP_100'] = 0
df.loc[~(df['AFP'] < 100), 'AFP_100'] = 1
df['AFP_100'].value_counts()
# Out:
# 0    4029
# 1    1770
# Name: AFP_100, dtype: int64

# %% [markdown]
# ## L3

# %%
#cut += df['L3'].isnull().sum()
df['L3'].isnull().sum()
# Out:
# 454

# %%
#L3は0埋め
df['L3'] = df['L3'].fillna(0).astype(float)
df.insert(loc=0, column='L3_10', value= -1)
df.loc[df['L3'] < 10, 'L3_10'] = 0
df.loc[~(df['L3'] < 10), 'L3_10'] = 1
df['L3_10'].value_counts()
# Out:
# 0    3752
# 1    2047
# Name: L3_10, dtype: int64

# %%
df['L3_10'] = df['L3_10'].fillna(0).astype(int)
df['L3_10'].value_counts()
# Out:
# 0    3752
# 1    2047
# Name: L3_10, dtype: int64

# %% [markdown]
# ## PIVKA

# %%
#cut += df['PIVKA'].isnull().sum()
df['PIVKA'].isnull().sum()
# Out:
# 120

# %%
#PIVKAは0埋め
df['PIVKA'] = df['PIVKA'].fillna(0).astype(float)
df.insert(loc=0, column='PIVKA_100', value= -1)
df.loc[df['PIVKA'] < 100, 'PIVKA_100'] = 0
df.loc[~(df['PIVKA'] < 100), 'PIVKA_100'] = 1
df['PIVKA_100'].value_counts()
# Out:
# 0    3105
# 1    2694
# Name: PIVKA_100, dtype: int64

# %% [markdown]
# ## Vp_grade

# %%
df['Vp_grade'].value_counts()
# Out:
# 0    5413
# 2     139
# 3     105
# 4      99
# 1      43
# Name: Vp_grade, dtype: int64

# %%
cut += df['Vp_grade'].isnull().sum()
df['Vp_grade'].isnull().sum()
# Out:
# 0

# %%
df['Vp_grade'] = df['Vp_grade'].replace(2,  1).replace(3, 1).replace(4, 1)
df['Vp_grade'].value_counts()
# Out:
# 0    5413
# 1     386
# Name: Vp_grade, dtype: int64

# %% [markdown]
# ## meta_positive

# %%
df['Meta0or1'].value_counts()
# Out:
# 0.0    5430
# 1.0     338
# 2.0       1
# Name: Meta0or1, dtype: int64

# %%
cut += df['Meta0or1'].isnull().sum()
df['Meta0or1'].isnull().sum()
# Out:
# 30

# %%
df = df.dropna(subset=['Meta0or1'])
df['Meta0or1'] = df['Meta0or1'].replace(2, 1).astype(int)
df['Meta0or1'].value_counts()
# Out:
# <ipython-input-52-0d8ae57c29dd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Meta0or1'] = df['Meta0or1'].replace(2, 1).astype(int)
# 0    5430
# 1     339
# Name: Meta0or1, dtype: int64

# %% [markdown]
# ## etiology

# %%
df['etiology_C1B2BC3Alc4NBNC5'].value_counts()
# Out:
# 1.0    3834
# 5.0     921
# 4.0     472
# 2.0     462
# 3.0      70
# Name: etiology_C1B2BC3Alc4NBNC5, dtype: int64

# %%
cut += df['etiology_C1B2BC3Alc4NBNC5'].isnull().sum()
df['etiology_C1B2BC3Alc4NBNC5'].isnull().sum()
# Out:
# 10

# %%
df = df.dropna(subset=['etiology_C1B2BC3Alc4NBNC5'])
df = df.rename(columns={'etiology_C1B2BC3Alc4NBNC5': 'etiology_class'})
df['etiology_class'] = df['etiology_class'].replace(1,  'C').replace(2, 'B').replace(3, 'BC').replace(4, 'Alc').replace(5, 'NBNC')
df['etiology_class'].value_counts()
# Out:
# C       3834
# NBNC     921
# Alc      472
# B        462
# BC        70
# Name: etiology_class, dtype: int64

# %%
df = pd.get_dummies(df, columns=['etiology_class'])
df.loc[df['etiology_class_BC'] == 1, 'etiology_class_B'] = 1
df.loc[df['etiology_class_BC'] == 1, 'etiology_class_C'] = 1
df = df.drop(columns=['etiology_class_BC', 'etiology_class_NBNC'])
df
# Out:
#       PIVKA_100  L3_10  AFP_100        ID          BD  肝癌症例   Age  Gender  \
# 0             0      0        1  11359162  1925/07/02     1  74.0       0
# 3             1      1        1  20146876  1948/07/02     1  65.0       0
# 4             0      0        0  13170941  1929/04/19     1  74.0       0
# 7             0      0        1  20197511  1936/11/20     1  81.0       0
# 8             1      1        1  15371855  1934/02/02     1  69.0       0
# ...         ...    ...      ...       ...         ...   ...   ...     ...
# 6379          0      1        0  11338154  1925/02/13     1  83.0       0
# 6380          0      1        0  11338154  1925/02/13     1  85.0       0
# 6381          0      1        0  11338154  1925/02/13     1  86.0       0
# 6382          0      0        0  11338154  1925/02/13     1  86.0       0
# 6383          0      0        0  17453700  1948/01/29     1  71.0       0
#
#       初回治療  No_of_Admission  naïveHCC       初回入院日         入院日  Last_Treatment  \
# 0     PEIT                1       1.0  2000/04/10  2000/04/10        4.000043
# 3      無治療                1       1.0  2014/05/08  2014/05/08        4.000043
# 4      TAE                1       1.0  2003/12/02  2003/12/02        4.000043
# 7      OPE                1       1.0  2018/02/07  2018/02/07        4.000043
# 8      RFA                1       1.0  2003/08/04  2003/08/04        4.000043
# ...    ...              ...       ...         ...         ...             ...
# 6379  PEIT                7       NaN         NaN  2008/06/02        2.146128
# 6380  PEIT                8       NaN         NaN  2010/03/15        2.814248
# 6381  PEIT                9       NaN         NaN  2011/02/21        2.536558
# 6382  PEIT               10       NaN         NaN  2011/07/04        2.127105
# 6383   OPE                1       1.0  2019/07/18  2019/07/18        4.000043
#
#      basal_disease    etiology  HCV  HBV  nonBnonC     HT    BW        BMI  \
# 0               LC           C  1.0  0.0       0.0    NaN   NaN  23.553545
# 3               LC           C  1.0  0.0       0.0  1.644  50.4  18.647770
# 4         nonBnonC    nonBnonC  0.0  0.0       1.0    NaN   NaN  23.553545
# 7               CH  C(DAA SVR)  1.0  0.0       0.0  1.510  51.5  22.586729
# 8               LC           C  1.0  0.0       0.0  1.600    55  21.484375
# ...            ...         ...  ...  ...       ...    ...   ...        ...
# 6379            CH           C  1.0  NaN       NaN    NaN   NaN  23.553545
# 6380            CH           C  1.0  NaN       NaN    NaN   NaN  23.553545
# 6381            CH           C  1.0  NaN       NaN    NaN   NaN  23.553545
# 6382            CH           C  1.0  NaN       NaN    NaN   NaN  23.553545
# 6383            CH  C(IFN SVR)  1.0  0.0       0.0  1.620    77  29.340040
#
#        PS    AST    ALT   Plt  T.Bil  Alb     PT PT.INR     AFP    L3  \
# 0     NaN  200.0  294.0  10.0    0.9  4.0   98.3   1.01   129.8   0.0
# 3     0.0  194.0  100.0  19.9    3.6  3.3   74.0   1.17  1020.0  70.9
# 4     NaN   44.0   16.0  16.5    0.5  3.7   99.6   1.01     3.6   0.0
# 7     0.0   27.0   33.0  19.3    0.5  4.3   84.0    1.1   134.3   0.0
# 8     0.0   59.0   44.0  22.4    0.9  3.5   87.5    NaN   152.7  35.9
# ...   ...    ...    ...   ...    ...  ...    ...    ...     ...   ...
# 6379  NaN   35.0   30.0  33.0    0.7  4.0   74.1    NaN     5.1  22.8
# 6380  NaN   22.0   13.0  20.0    0.4  3.6   84.6    NaN     2.8  18.2
# 6381  NaN   20.0   17.0  19.4    0.4  3.6   90.2   1.05     7.6  56.4
# 6382  NaN   29.0   23.0  19.4    0.5  4.0   95.9   1.03     2.5   0.0
# 6383  0.0   40.0   52.0  15.8    1.0  4.5  108.0   0.96     3.5   0.5
#
#          PIVKA      FIB4  ALBI_score  HCC_size  HCC_No HCC実数  Vp_grade  \
# 0         18.0  8.631535         262         4       1     1         0
# 3     211840.0  6.336683         162         7       3     3         1
# 4         23.0  4.933333         253        12       1     1         1
# 7         62.0  1.972579         304         2       1     1         0
# 8        720.0  2.739850         219         3       1     1         0
# ...        ...       ...         ...       ...     ...   ...       ...
# 6379      70.0  1.607206         269         2       3     3         0
# 6380      13.0  2.593223         251         1       1     1         0
# 6381      13.0  2.150316         251         2       2     2         0
# 6382       9.0  2.680593         278         1       2     2         0
# 6383      46.0  2.492640         301         1       2     1         0
#
#       Meta0or1  Death1Alive0       入院日.1   最終観察日_退院日 OS_day     OS_Month  \
# 0            0             1  2000/04/17  2001/12/24    616  20.53333333
# 3            0             1  2014/05/08  2014/07/12     65  2.166666667
# 4            0             1  2003/12/04  2004/09/15    286  9.533333333
# 7            0             0  2018/02/07  2022/03/08   1490  49.66666667
# 8            0             1  2003/08/06  2006/04/25    993         33.1
# ...        ...           ...         ...         ...    ...          ...
# 6379         0             1  2008/06/02  2011/11/21   1267  42.23333333
# 6380         0             1  2010/03/15  2011/11/21    616  20.53333333
# 6381         0             1  2011/02/21  2011/11/21    273          9.1
# 6382         0             1  2011/07/04  2011/11/21    140  4.666666667
# 6383         0             0  2019/07/18  2020/04/03    260  8.666666667
#
#            死亡年月日   死因        GNRI  GNRI栄養リスク1良4最悪  男性標準体重  女性標準体重  Ablation  \
# 0     2001/12/24  肝癌死         NaN             NaN     NaN     NaN         1
# 3            NaN  肝不全   83.704105             3.0   60.80     NaN         0
# 4     2004/09/15  肝癌死         NaN             NaN     NaN     NaN         0
# 7            NaN  NaN  106.343256             1.0   50.75     NaN         0
# 8            NaN  肝癌死   92.001957             2.0   57.50     NaN         1
# ...          ...  ...         ...             ...     ...     ...       ...
# 6379         NaN  NaN         NaN             NaN     NaN     NaN         1
# 6380         NaN  NaN         NaN             NaN     NaN     NaN         0
# 6381         NaN  NaN         NaN             NaN     NaN     NaN         0
# 6382         NaN  NaN         NaN             NaN     NaN     NaN         0
# 6383         NaN  NaN  121.427034             1.0   59.00     NaN         0
#
#       OPE  TAE  MTA  Radiation  No_Cumsum  NoSize  NoSize_Cumsum  PS_Raw  \
# 0       0    0    0          0          1       4              0       0
# 3       0    0    0          0          3      21              2       0
# 4       0    1    0          0          1      12              1       0
# 7       1    0    0          0          1       2              0       0
# 8       0    0    0          0          1       3              0       0
# ...   ...  ...  ...        ...        ...     ...            ...     ...
# 6379    0    0    0          0         11       6              2       0
# 6380    0    1    0          0         12       1              2       0
# 6381    0    1    0          0         14       4              2       0
# 6382    0    1    0          0         16       2              3       0
# 6383    1    0    0          0          2       2              0       0
#
#       ALBI_grade_2  ALBI_grade_3  ALBI_grade_4  etiology_class_Alc  \
# 0                0             0             0                   0
# 3                0             1             0                   0
# 4                1             0             0                   0
# 7                0             0             0                   0
# 8                0             1             0                   0
# ...            ...           ...           ...                 ...
# 6379             0             0             0                   0
# 6380             1             0             0                   0
# 6381             1             0             0                   0
# 6382             0             0             0                   0
# 6383             0             0             0                   0
#
#       etiology_class_B  etiology_class_C
# 0                    0                 1
# 3                    0                 1
# 4                    0                 0
# 7                    0                 1
# 8                    0                 1
# ...                ...               ...
# 6379                 0                 1
# 6380                 0                 1
# 6381                 0                 1
# 6382                 0                 1
# 6383                 0                 1
#
# [5759 rows x 66 columns]

# %% [markdown]
# ## OS

# %%
df['OS_day'] = df['OS_day'].replace('#VALUE!', np.nan).replace('#REF!', np.nan)
cut += df['OS_day'].isnull().sum()
df['OS_day'].isnull().sum()
# Out:
# 7

# %%
df = df.dropna(subset=['OS_day'])
df['OS_day'] = df['OS_day'].astype(int)
df['OS_day'].unique()
# Out:
# <ipython-input-58-cb13f3fd9680>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['OS_day'] = df['OS_day'].astype(int)
# array([ 616,   65,  286, ..., 2035, 1775, 1406])

# %% [markdown]
# ## 肝臓がんのみを抽出

# %%
df['肝癌症例'].value_counts()
# Out:
# 1    5701
# 0      51
# Name: 肝癌症例, dtype: int64

# %%
cut += len(df[df['肝癌症例']==0])
len(df[df['肝癌症例']==0])
# Out:
# 51

# %%
df = df[df['肝癌症例'] == 1]

# %% [markdown]
# ## dfとcutの確認

# %%
df
# Out:
#       PIVKA_100  L3_10  AFP_100        ID          BD  肝癌症例   Age  Gender  \
# 0             0      0        1  11359162  1925/07/02     1  74.0       0
# 3             1      1        1  20146876  1948/07/02     1  65.0       0
# 4             0      0        0  13170941  1929/04/19     1  74.0       0
# 7             0      0        1  20197511  1936/11/20     1  81.0       0
# 8             1      1        1  15371855  1934/02/02     1  69.0       0
# ...         ...    ...      ...       ...         ...   ...   ...     ...
# 6379          0      1        0  11338154  1925/02/13     1  83.0       0
# 6380          0      1        0  11338154  1925/02/13     1  85.0       0
# 6381          0      1        0  11338154  1925/02/13     1  86.0       0
# 6382          0      0        0  11338154  1925/02/13     1  86.0       0
# 6383          0      0        0  17453700  1948/01/29     1  71.0       0
#
#       初回治療  No_of_Admission  naïveHCC       初回入院日         入院日  Last_Treatment  \
# 0     PEIT                1       1.0  2000/04/10  2000/04/10        4.000043
# 3      無治療                1       1.0  2014/05/08  2014/05/08        4.000043
# 4      TAE                1       1.0  2003/12/02  2003/12/02        4.000043
# 7      OPE                1       1.0  2018/02/07  2018/02/07        4.000043
# 8      RFA                1       1.0  2003/08/04  2003/08/04        4.000043
# ...    ...              ...       ...         ...         ...             ...
# 6379  PEIT                7       NaN         NaN  2008/06/02        2.146128
# 6380  PEIT                8       NaN         NaN  2010/03/15        2.814248
# 6381  PEIT                9       NaN         NaN  2011/02/21        2.536558
# 6382  PEIT               10       NaN         NaN  2011/07/04        2.127105
# 6383   OPE                1       1.0  2019/07/18  2019/07/18        4.000043
#
#      basal_disease    etiology  HCV  HBV  nonBnonC     HT    BW        BMI  \
# 0               LC           C  1.0  0.0       0.0    NaN   NaN  23.553545
# 3               LC           C  1.0  0.0       0.0  1.644  50.4  18.647770
# 4         nonBnonC    nonBnonC  0.0  0.0       1.0    NaN   NaN  23.553545
# 7               CH  C(DAA SVR)  1.0  0.0       0.0  1.510  51.5  22.586729
# 8               LC           C  1.0  0.0       0.0  1.600    55  21.484375
# ...            ...         ...  ...  ...       ...    ...   ...        ...
# 6379            CH           C  1.0  NaN       NaN    NaN   NaN  23.553545
# 6380            CH           C  1.0  NaN       NaN    NaN   NaN  23.553545
# 6381            CH           C  1.0  NaN       NaN    NaN   NaN  23.553545
# 6382            CH           C  1.0  NaN       NaN    NaN   NaN  23.553545
# 6383            CH  C(IFN SVR)  1.0  0.0       0.0  1.620    77  29.340040
#
#        PS    AST    ALT   Plt  T.Bil  Alb     PT PT.INR     AFP    L3  \
# 0     NaN  200.0  294.0  10.0    0.9  4.0   98.3   1.01   129.8   0.0
# 3     0.0  194.0  100.0  19.9    3.6  3.3   74.0   1.17  1020.0  70.9
# 4     NaN   44.0   16.0  16.5    0.5  3.7   99.6   1.01     3.6   0.0
# 7     0.0   27.0   33.0  19.3    0.5  4.3   84.0    1.1   134.3   0.0
# 8     0.0   59.0   44.0  22.4    0.9  3.5   87.5    NaN   152.7  35.9
# ...   ...    ...    ...   ...    ...  ...    ...    ...     ...   ...
# 6379  NaN   35.0   30.0  33.0    0.7  4.0   74.1    NaN     5.1  22.8
# 6380  NaN   22.0   13.0  20.0    0.4  3.6   84.6    NaN     2.8  18.2
# 6381  NaN   20.0   17.0  19.4    0.4  3.6   90.2   1.05     7.6  56.4
# 6382  NaN   29.0   23.0  19.4    0.5  4.0   95.9   1.03     2.5   0.0
# 6383  0.0   40.0   52.0  15.8    1.0  4.5  108.0   0.96     3.5   0.5
#
#          PIVKA      FIB4  ALBI_score  HCC_size  HCC_No HCC実数  Vp_grade  \
# 0         18.0  8.631535         262         4       1     1         0
# 3     211840.0  6.336683         162         7       3     3         1
# 4         23.0  4.933333         253        12       1     1         1
# 7         62.0  1.972579         304         2       1     1         0
# 8        720.0  2.739850         219         3       1     1         0
# ...        ...       ...         ...       ...     ...   ...       ...
# 6379      70.0  1.607206         269         2       3     3         0
# 6380      13.0  2.593223         251         1       1     1         0
# 6381      13.0  2.150316         251         2       2     2         0
# 6382       9.0  2.680593         278         1       2     2         0
# 6383      46.0  2.492640         301         1       2     1         0
#
#       Meta0or1  Death1Alive0       入院日.1   最終観察日_退院日  OS_day     OS_Month  \
# 0            0             1  2000/04/17  2001/12/24     616  20.53333333
# 3            0             1  2014/05/08  2014/07/12      65  2.166666667
# 4            0             1  2003/12/04  2004/09/15     286  9.533333333
# 7            0             0  2018/02/07  2022/03/08    1490  49.66666667
# 8            0             1  2003/08/06  2006/04/25     993         33.1
# ...        ...           ...         ...         ...     ...          ...
# 6379         0             1  2008/06/02  2011/11/21    1267  42.23333333
# 6380         0             1  2010/03/15  2011/11/21     616  20.53333333
# 6381         0             1  2011/02/21  2011/11/21     273          9.1
# 6382         0             1  2011/07/04  2011/11/21     140  4.666666667
# 6383         0             0  2019/07/18  2020/04/03     260  8.666666667
#
#            死亡年月日   死因        GNRI  GNRI栄養リスク1良4最悪  男性標準体重  女性標準体重  Ablation  \
# 0     2001/12/24  肝癌死         NaN             NaN     NaN     NaN         1
# 3            NaN  肝不全   83.704105             3.0   60.80     NaN         0
# 4     2004/09/15  肝癌死         NaN             NaN     NaN     NaN         0
# 7            NaN  NaN  106.343256             1.0   50.75     NaN         0
# 8            NaN  肝癌死   92.001957             2.0   57.50     NaN         1
# ...          ...  ...         ...             ...     ...     ...       ...
# 6379         NaN  NaN         NaN             NaN     NaN     NaN         1
# 6380         NaN  NaN         NaN             NaN     NaN     NaN         0
# 6381         NaN  NaN         NaN             NaN     NaN     NaN         0
# 6382         NaN  NaN         NaN             NaN     NaN     NaN         0
# 6383         NaN  NaN  121.427034             1.0   59.00     NaN         0
#
#       OPE  TAE  MTA  Radiation  No_Cumsum  NoSize  NoSize_Cumsum  PS_Raw  \
# 0       0    0    0          0          1       4              0       0
# 3       0    0    0          0          3      21              2       0
# 4       0    1    0          0          1      12              1       0
# 7       1    0    0          0          1       2              0       0
# 8       0    0    0          0          1       3              0       0
# ...   ...  ...  ...        ...        ...     ...            ...     ...
# 6379    0    0    0          0         11       6              2       0
# 6380    0    1    0          0         12       1              2       0
# 6381    0    1    0          0         14       4              2       0
# 6382    0    1    0          0         16       2              3       0
# 6383    1    0    0          0          2       2              0       0
#
#       ALBI_grade_2  ALBI_grade_3  ALBI_grade_4  etiology_class_Alc  \
# 0                0             0             0                   0
# 3                0             1             0                   0
# 4                1             0             0                   0
# 7                0             0             0                   0
# 8                0             1             0                   0
# ...            ...           ...           ...                 ...
# 6379             0             0             0                   0
# 6380             1             0             0                   0
# 6381             1             0             0                   0
# 6382             0             0             0                   0
# 6383             0             0             0                   0
#
#       etiology_class_B  etiology_class_C
# 0                    0                 1
# 3                    0                 1
# 4                    0                 0
# 7                    0                 1
# 8                    0                 1
# ...                ...               ...
# 6379                 0                 1
# 6380                 0                 1
# 6381                 0                 1
# 6382                 0                 1
# 6383                 0                 1
#
# [5701 rows x 66 columns]

# %%
cut
# Out:
# 683

# %%
##before = len(df)
##df['入院日'] = pd.to_datetime(df['入院日'])
##df = df.loc[df['入院日'].dt.year <= 2020]
##before - len(df)

# %% [markdown]
# ## One_Yearの作成

# %%
df['Death1Alive0'] = df['Death1Alive0'].astype(int)
df.insert(loc=0, column='One_Year', value= -1)
df.loc[(df['OS_day'] < 365) & (df['Death1Alive0'] == 1), 'One_Year'] = 0
df.loc[df['OS_day'] >= 365, 'One_Year'] = 1
df['One_Year'].value_counts()
# Out:
#  1    3956
#  0     988
# -1     757
# Name: One_Year, dtype: int64

# %%
## 1年後の生死が未確認（OS.day<365&Death1Alive0=0)を削除
df = df[df['One_Year'] != -1]

# %% [markdown]
# ## 学習データ

# %%
data = df.loc[:,['Ablation', 'OPE', 'TAE', 'MTA', 'Radiation', 'Last_Treatment', 'Age', 'Gender', 'BMI', 'No_of_Admission', 'HCC_No', 'No_Cumsum', 
                 'HCC_size', 'NoSize', 'NoSize_Cumsum', 'PS_Raw', 'ALBI_score', 'AFP_100', 'L3_10', 'PIVKA_100', 
                 'Vp_grade', 'Meta0or1', 'etiology_class_C', 'etiology_class_B', 'etiology_class_Alc']]
target = df['One_Year']
data
# Out:
#       Ablation  OPE  TAE  MTA  Radiation  Last_Treatment   Age  Gender  \
# 0            1    0    0    0          0        4.000043  74.0       0
# 3            0    0    0    0          0        4.000043  65.0       0
# 4            0    0    1    0          0        4.000043  74.0       0
# 7            0    1    0    0          0        4.000043  81.0       0
# 8            1    0    0    0          0        4.000043  69.0       0
# ...        ...  ...  ...  ...        ...             ...   ...     ...
# 6378         1    0    0    0          0        2.262451  82.0       0
# 6379         1    0    0    0          0        2.146128  83.0       0
# 6380         0    0    1    0          0        2.814248  85.0       0
# 6381         0    0    1    0          0        2.536558  86.0       0
# 6382         0    0    1    0          0        2.127105  86.0       0
#
#             BMI  No_of_Admission  HCC_No  No_Cumsum  HCC_size  NoSize  \
# 0     23.553545                1       1          1         4       4
# 3     18.647770                1       3          3         7      21
# 4     23.553545                1       1          1        12      12
# 7     22.586729                1       1          1         2       2
# 8     21.484375                1       1          1         3       3
# ...         ...              ...     ...        ...       ...     ...
# 6378  23.553545                6       1          8         1       1
# 6379  23.553545                7       3         11         2       6
# 6380  23.553545                8       1         12         1       1
# 6381  23.553545                9       2         14         2       4
# 6382  23.553545               10       2         16         1       2
#
#       NoSize_Cumsum  PS_Raw  ALBI_score  AFP_100  L3_10  PIVKA_100  Vp_grade  \
# 0                 0       0         262        1      0          0         0
# 3                 2       0         162        1      1          1         1
# 4                 1       0         253        0      0          0         1
# 7                 0       0         304        1      0          0         0
# 8                 0       0         219        1      1          1         0
# ...             ...     ...         ...      ...    ...        ...       ...
# 6378              1       0         285        0      0          0         0
# 6379              2       0         269        0      1          0         0
# 6380              2       0         251        0      1          0         0
# 6381              2       0         251        0      1          0         0
# 6382              3       0         278        0      0          0         0
#
#       Meta0or1  etiology_class_C  etiology_class_B  etiology_class_Alc
# 0            0                 1                 0                   0
# 3            0                 1                 0                   0
# 4            0                 0                 0                   0
# 7            0                 1                 0                   0
# 8            0                 1                 0                   0
# ...        ...               ...               ...                 ...
# 6378         0                 1                 0                   0
# 6379         0                 1                 0                   0
# 6380         0                 1                 0                   0
# 6381         0                 1                 0                   0
# 6382         0                 1                 0                   0
#
# [4944 rows x 25 columns]

# %%
data.dtypes
# Out:
# Ablation                uint8
# OPE                     uint8
# TAE                     uint8
# MTA                     uint8
# Radiation               uint8
# Last_Treatment        float64
# Age                   float64
# Gender                  int64
# BMI                   float64
# No_of_Admission         int64
# HCC_No                  int64
# No_Cumsum               int64
# HCC_size                int64
# NoSize                  int64
# NoSize_Cumsum           int64
# PS_Raw                  int64
# ALBI_score              int64
# AFP_100                 int64
# L3_10                   int64
# PIVKA_100               int64
# Vp_grade                int64
# Meta0or1                int64
# etiology_class_C        uint8
# etiology_class_B        uint8
# etiology_class_Alc      uint8
# dtype: object

# %% [markdown]
# # TrainとValidの作成

# %%
x_train, x_valid, y_train, y_valid = train_test_split(data, target, train_size = 0.8, random_state = 5)

# %%
x_train.head()
# Out:
#       Ablation  OPE  TAE  MTA  Radiation  Last_Treatment   Age  Gender  \
# 3036         0    1    0    0          0        4.000043  77.0       1
# 6030         0    0    1    0          0        2.103804  74.0       1
# 952          1    0    0    0          0        2.894316  78.0       0
# 5100         0    0    1    0          0        3.286456  73.0       1
# 6283         0    0    1    0          0        4.000043  83.0       1
#
#             BMI  No_of_Admission  HCC_No  No_Cumsum  HCC_size  NoSize  \
# 3036  25.414247                1       1          1         1       1
# 6030  21.504470                3       3         13         2       6
# 952   23.553545                2       2          3         2       4
# 5100  23.553545                6       5         12         2      10
# 6283  26.985466                1       4          4         1       4
#
#       NoSize_Cumsum  PS_Raw  ALBI_score  AFP_100  L3_10  PIVKA_100  Vp_grade  \
# 3036              0       1         177        0      0          0         0
# 6030              2       0         228        0      0          0         0
# 952               1       0         278        0      0          1         0
# 5100              2       0         222        0      1          0         0
# 6283              0       0         202        0      0          0         0
#
#       Meta0or1  etiology_class_C  etiology_class_B  etiology_class_Alc
# 3036         0                 1                 0                   0
# 6030         0                 1                 0                   0
# 952          0                 0                 0                   0
# 5100         0                 1                 0                   0
# 6283         0                 1                 0                   0

# %%
corr_inv = np.linalg.inv(np.array(x_train.corr()))
vif = pd.Series(np.diag(corr_inv), index=x_train.columns)
pd.options.display.float_format = '{:.2f}'.format
vif
# Out:
# Ablation              8.34
# OPE                   4.93
# TAE                   9.22
# MTA                   3.50
# Radiation             1.11
# Last_Treatment        2.44
# Age                   1.17
# Gender                1.10
# BMI                   1.03
# No_of_Admission       7.80
# HCC_No                5.71
# No_Cumsum            17.06
# HCC_size              3.44
# NoSize                6.74
# NoSize_Cumsum         9.01
# PS_Raw                1.19
# ALBI_score            1.24
# AFP_100               1.45
# L3_10                 1.45
# PIVKA_100             1.35
# Vp_grade              1.30
# Meta0or1              1.31
# etiology_class_C      1.79
# etiology_class_B      1.44
# etiology_class_Alc    1.43
# dtype: float64

# %%
x_train = x_train.drop('No_Cumsum', axis=1)
x_train_columns = x_train.columns.values.tolist()
print(x_train_columns)
# Out:
# ['Ablation', 'OPE', 'TAE', 'MTA', 'Radiation', 'Last_Treatment', 'Age', 'Gender', 'BMI', 'No_of_Admission', 'HCC_No', 'HCC_size', 'NoSize', 'NoSize_Cumsum', 'PS_Raw', 'ALBI_score', 'AFP_100', 'L3_10', 'PIVKA_100', 'Vp_grade', 'Meta0or1', 'etiology_class_C', 'etiology_class_B', 'etiology_class_Alc']

# %%
train_data = x_train.join(y_train)
train_data
# Out:
#       Ablation  OPE  TAE  MTA  Radiation  Last_Treatment   Age  Gender   BMI  \
# 3036         0    1    0    0          0            4.00 77.00       1 25.41
# 6030         0    0    1    0          0            2.10 74.00       1 21.50
# 952          1    0    0    0          0            2.89 78.00       0 23.55
# 5100         0    0    1    0          0            3.29 73.00       1 23.55
# 6283         0    0    1    0          0            4.00 83.00       1 26.99
# ...        ...  ...  ...  ...        ...             ...   ...     ...   ...
# 3976         1    0    0    0          0            2.73 61.00       0 23.55
# 2226         1    0    0    0          0            4.00 62.00       0 21.90
# 5268         1    0    0    0          0            3.17 82.00       1 23.55
# 2909         0    0    1    0          0            2.19 68.00       0 23.55
# 3803         0    1    0    0          0            4.00 87.00       0 21.91
#
#       No_of_Admission  HCC_No  HCC_size  NoSize  NoSize_Cumsum  PS_Raw  \
# 3036                1       1         1       1              0       1
# 6030                3       3         2       6              2       0
# 952                 2       2         2       4              1       0
# 5100                6       5         2      10              2       0
# 6283                1       4         1       4              0       0
# ...               ...     ...       ...     ...            ...     ...
# 3976                2       2         2       4              1       0
# 2226                1       1         1       1              0       0
# 5268                2       1         1       1              0       0
# 2909                5       6         3      18              5       0
# 3803                1       1         3       3              0       1
#
#       ALBI_score  AFP_100  L3_10  PIVKA_100  Vp_grade  Meta0or1  \
# 3036         177        0      0          0         0         0
# 6030         228        0      0          0         0         0
# 952          278        0      0          1         0         0
# 5100         222        0      1          0         0         0
# 6283         202        0      0          0         0         0
# ...          ...      ...    ...        ...       ...       ...
# 3976         282        0      1          0         0         0
# 2226         319        0      0          0         0         0
# 5268         196        0      0          0         0         0
# 2909         140        1      1          1         0         0
# 3803         234        0      1          1         0         0
#
#       etiology_class_C  etiology_class_B  etiology_class_Alc  One_Year
# 3036                 1                 0                   0         1
# 6030                 1                 0                   0         1
# 952                  0                 0                   0         1
# 5100                 1                 0                   0         1
# 6283                 1                 0                   0         1
# ...                ...               ...                 ...       ...
# 3976                 1                 0                   0         1
# 2226                 1                 0                   0         1
# 5268                 1                 0                   0         1
# 2909                 1                 0                   0         1
# 3803                 0                 0                   0         1
#
# [3955 rows x 25 columns]

# %%
def stepAIC(descs_l):
    import copy
    descriptors = descs_l
    f_model = smf.glm(formula='One_Year ~ ' + ' + '.join(descriptors),
                      data=train_data, family=sm.families.Binomial()).fit()
    best_aic = f_model.aic
    best_model = f_model
    while descriptors:
        desc_selected = ''
        flag = 0
        for desk in descriptors:
            used_desks = copy.deepcopy(descriptors)
            used_desks.remove(desk)
            formula = 'One_Year ~ ' + ' + '.join(used_desks)
            model = smf.glm(formula=formula, 
                            data=train_data, family=sm.families.Binomial()).fit()
            if model.aic < best_aic:
                best_aic = model.aic
                best_model = model
                desc_selected = desk
                flag = 1
        if flag:
            descriptors.remove(desc_selected)
        else:
            break
    return best_model
 
model = stepAIC(x_train_columns)
print(model.summary().tables[1])
# Out:
# ===================================================================================
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           1.1928      0.498      2.394      0.017       0.216       2.169
# Ablation            1.9061      0.273      6.988      0.000       1.371       2.441
# OPE                 2.4341      0.306      7.965      0.000       1.835       3.033
# TAE                 1.8652      0.246      7.573      0.000       1.382       2.348
# MTA                 1.2624      0.278      4.534      0.000       0.717       1.808
# Age                -0.0194      0.006     -3.477      0.001      -0.030      -0.008
# No_of_Admission    -0.0617      0.016     -3.813      0.000      -0.093      -0.030
# HCC_No             -0.1382      0.030     -4.589      0.000      -0.197      -0.079
# HCC_size           -0.1675      0.024     -6.952      0.000      -0.215      -0.120
# ALBI_score          0.0097      0.001     11.246      0.000       0.008       0.011
# AFP_100            -0.4853      0.116     -4.183      0.000      -0.713      -0.258
# L3_10              -0.4365      0.117     -3.737      0.000      -0.665      -0.208
# PIVKA_100          -0.7779      0.114     -6.818      0.000      -1.002      -0.554
# Vp_grade           -1.4668      0.207     -7.100      0.000      -1.872      -1.062
# Meta0or1           -0.9560      0.211     -4.536      0.000      -1.369      -0.543
# ===================================================================================

# %%
ddf = pd.DataFrame({'model': model.predict()})
ddf['model_p'] = ddf.model.map(lambda x: 1 if x >= 0.5 else 0)
ddf['exp'] = np.array(train_data.One_Year)
 
correct_count = len(ddf[ ddf.model_p == ddf.exp ])
print(correct_count)
print(correct_count/len(train_data))
# Out:
# 3397
# 0.8589127686472819

# %%
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score

cm = confusion_matrix(train_data.One_Year, ddf.model_p)
cm
# Out:
# array([[ 354,  419],
#        [ 139, 3043]])

# %%
eq = np.zeros(len(train_data))
for i,j in zip(model.params.index, model.params.values):
    if i == 'Intercept':
        eq += np.array([j])
    else:
        eq += j*np.array(train_data[i])
        
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(eq, train_data.One_Year, marker='o', alpha=0.3)
ax.plot(np.sort(eq), 1/(1+(np.exp(-np.sort(eq)))), 'k-', lw=2)
ax.set_ylabel('Result')
# Out:
# Text(0, 0.5, 'Result')

# %%
ddf.exp
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 3950    1
# 3951    1
# 3952    1
# 3953    1
# 3954    1
# Name: exp, Length: 3955, dtype: int64

# %%
ddf.model_p
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 3950    1
# 3951    1
# 3952    1
# 3953    0
# 3954    1
# Name: model_p, Length: 3955, dtype: int64

# %%
# ROC曲線の値の生成：fpr、tpr、閾値
fpr, tpr, thresholds = roc_curve(ddf.exp, ddf.model)

# ROC曲線のプロット
plt.figure(figsize=(6, 6))
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr, tpr, label='Logistic Regression')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
#plt.savefig('results/0111_Test_ROC_1year.jpg', dpi=300)
plt.show()

#AUCの表示
auc_GLM = roc_auc_score(ddf.exp, ddf.model)
print(auc_GLM)
# Out:
# 0.8710725677993045

# %%
def roc_auc_ci(y_true, y_score, positive=1):
    AUC = roc_auc_score(y_true, y_score)
    N1 = sum(y_true == positive)
    N2 = sum(y_true != positive)
    Q1 = AUC / (2 - AUC)
    Q2 = 2*AUC**2 / (1 + AUC)
    SE_AUC = math.sqrt((AUC*(1 - AUC) + (N1 - 1)*(Q1 - AUC**2) + (N2 - 1)*(Q2 - AUC**2)) / (N1*N2))
    lower = AUC - 1.96*SE_AUC
    upper = AUC + 1.96*SE_AUC
    if lower < 0:
        lower = 0
    if upper > 1:
        upper = 1
    return (lower, upper)

roc_auc_ci(ddf.exp, ddf.model)
# Out:
# (0.8598060305083605, 0.8823391050902486)

# %%
def _proportion_confidence_interval(r, n, z):
    A = 2*r + z**2
    B = z*math.sqrt(z**2 + 4*r*(1 - r/n))
    C = 2*(n + z**2)
    return ((A-B)/C, (A+B)/C)

def sensitivity_and_specificity_with_confidence_intervals(TP, FP, FN, TN, alpha):
    
    z = -ndtri((1.0-alpha)/2)
    
    sensitivity_point_estimate = TP/(TP + FN)
    sensitivity_confidence_interval = _proportion_confidence_interval(TP, TP + FN, z)
    
    specificity_point_estimate = TN/(TN + FP)
    specificity_confidence_interval = _proportion_confidence_interval(TN, TN + FP, z)
    
    return sensitivity_point_estimate, specificity_point_estimate, sensitivity_confidence_interval, specificity_confidence_interval

sensitivity_and_specificity_with_confidence_intervals(cm[1][1], cm[0][1], cm[1][0], cm[0][0], 0.95)
# Out:
# (0.9563167818981773,
#  0.4579560155239327,
#  (0.9486479459277195, 0.9628851725705803),
#  (0.423127585351252, 0.49320025830081693))

# %%
def viz_calibration_curve(y_test, y_pred, name):
    frac_of_pos, mean_pred_value = calibration_curve(y_test, y_pred, n_bins=10)

    fig, ax = plt.subplots(1, 2, figsize=(15,6))
    ax[0].plot([0, 1], [0, 1], "k:", label="Perfectly calibrated")
    ax[0].plot(mean_pred_value, frac_of_pos, marker="o", label=f'{name}')
    ax[0].set_ylabel("Fraction of positives")
    ax[0].set_ylim([-0.05, 1.05])
    ax[0].legend(loc="lower right")
    ax[0].set_title(f'Calibration plot 1year ({name})')
    
    sns.distplot(y_pred, bins=100, label='predicted score', ax=ax[1])
    ax[1].legend(loc='upper right')
    ax[1].set_xlim([-0.05, 1.05])
    #plt.savefig('results/0111_calibration_1year.jpg', dpi=300)
    plt.show()

# AUCとReliability Diagramの可視化
viz_calibration_curve(ddf.exp, ddf.model, 'GLM')
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#pickle.dump(model, open('models/0111_model_GLM_1year.pickle', 'wb'))
